# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge of join statements, using various types of joins and various methods for specifying the links between them.
#
# ## Objectives
#
# You will be able to:
# - Write queries that make use of various types of Joins
# - Join tables using foreign keys

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather then just working with a single table you will typically need data from multiple tables.
# Doing this requires the use of **joins ** using shared columns from the two tables.
#
# In this lab, you'll use the same Customer Relationship Management (CRM) database that you saw from the previous lesson.
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database **data.sqlite**.

# %%
import sqlite3
conn = sqlite3.connect('data.sqlite')
c = conn.cursor()

# %% [markdown]
# ## Display the names of all the employees in Boston.
# Hint: join the employees and offices tables.

# %%
c.execute("""
SELECT firstName, lastName 
FROM employees e JOIN offices o ON e.officeCode == o.officeCode
WHERE city == \'Boston\';
""").fetchall()
# Out:
# [('Julie', 'Firrelli'), ('Steve', 'Patterson')]

# %% [markdown]
# ## Do any offices have no employees?
# Hint: Combine the employees and offices tables and use a group by.

# %%
c.execute("""
SELECT count(employeeNumber), officeCode
FROM employees
GROUP BY officeCode;
""").fetchall()
# Out:
# [(6, '1'), (2, '2'), (2, '3'), (5, '4'), (2, '5'), (4, '6'), (2, '7')]

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
# Answers will vary

# %%
# Your code here

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# ## Level Up: Display the names of each product each employee has sold

# %%
c.execute("""
SELECT DISTINCT employeeNumber, productName
FROM (((products p JOIN orderdetails od on p.productcode == od.productcode) pod 
    JOIN orders o ON pod.orderNumber == o.orderNumber) podo
    JOIN customers c ON podo.customerNumber == c.customerNumber) podoc
    JOIN employees e ON podoc.salesRepEmployeeNumber == e.employeeNumber
ORDER BY employeeNumber;
""").fetchall()
# Out:
# [('1165', '1969 Harley Davidson Ultimate Chopper'),
#  ('1165', '1952 Alpine Renault 1300'),
#  ('1165', '1996 Moto Guzzi 1100i'),
#  ('1165', '2003 Harley-Davidson Eagle Drag Bike'),
#  ('1165', '1972 Alfa Romeo GTA'),
#  ('1165', '1962 LanciaA Delta 16V'),
#  ('1165', '1968 Ford Mustang'),
#  ('1165', '2001 Ferrari Enzo'),
#  ('1165', '1958 Setra Bus'),
#  ('1165', '2002 Suzuki XREO'),
#  ('1165', '1969 Corvair Monza'),
#  ('1165', '1968 Dodge Charger'),
#  ('1165', '1969 Ford Falcon'),
#  ('1165', '1970 Plymouth Hemi Cuda'),
#  ('1165', '1957 Chevy Pickup'),
#  ('1165', '1969 Dodge Charger'),
#  ('1165', '1940 Ford Pickup Truck'),
#  ('1165', '1993 Mazda RX-7'),
#  ('1165', '1937 Lincoln Berline'),
#  ('1165', '1936 Mercedes-Benz 500K Special Roadster'),
#  ('1165', '1965 Aston Martin DB5'),
#  ('1165', '1980s Black Hawk Helicopter'),
#  ('1165', '1917 Grand Touring Sedan'),
#  ('1165', '1948 Porsche 356-A Roadster'),
#  ('1165', '1995 Honda Civic'),
# ...

# %% [markdown]
# ## Level Up: Display the Number of Products each employee has sold

# %%
c.execute("""
SELECT employeeNumber, COUNT(productName)
FROM (((products p JOIN orderdetails od on p.productcode == od.productcode) pod 
    JOIN orders o ON pod.orderNumber == o.orderNumber) podo
    JOIN customers c ON podo.customerNumber == c.customerNumber) podoc
    JOIN employees e ON podoc.salesRepEmployeeNumber == e.employeeNumber
GROUP BY employeeNumber
ORDER BY employeeNumber;
""").fetchall()
# Out:
# [('1165', 331),
#  ('1166', 114),
#  ('1188', 124),
#  ('1216', 152),
#  ('1286', 142),
#  ('1323', 211),
#  ('1337', 177),
#  ('1370', 396),
#  ('1401', 272),
#  ('1501', 236),
#  ('1504', 220),
#  ('1611', 185),
#  ('1612', 185),
#  ('1621', 137),
#  ('1702', 114)]

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You now know how to use join statements, along with leveraging your foreign keys knowledge!
